# %% [markdown]
# # 03. Project Details

# %% [markdown]
# ### Importando as bibliotecas

# %%
import sys
sys.path.append('..')
import pandas as pd
import functions.fn_stats as fn_stats
import params.consts as consts

# %% [markdown]
# ### Lendo o dataset

# %%
df = pd.read_csv(consts.DATASET_RAW) # Armazenando o dataset em uma variável
# Out:
# C:\Users\mathe\AppData\Local\Temp\ipykernel_40324\3340244681.py:1: DtypeWarning: Columns (27,61,62,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(consts.DATASET_RAW) # Armazenando o dataset em uma variável

# %%
display(df.head(3)) # Exibindo as 3 primeiras linhas do dataset

display(df.tail(3)) # Exibindo as 3 últimas linhas do dataset
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  14063  https://www.airbnb.com/rooms/14063  20180414160018   2018-04-14
# 1  17878  https://www.airbnb.com/rooms/17878  20180414160018   2018-04-14
# 2  24480  https://www.airbnb.com/rooms/24480  20180414160018   2018-04-14
#
#                                 name  \
# 0               Living in a Postcard
# 1  Very Nice 2Br - Copacabana - WiFi
# 2   Nice and cozy near Ipanema Beach
#
#                                              summary  \
# 0  Besides the most iconic's view, our apartment ...
# 1  Please note that special rates apply for New Y...
# 2  My studio is located in the best  of Ipanema. ...
#
#                                                space  \
# 0                                                NaN
# 1  - large balcony which looks out on pedestrian ...
# 2  The studio is located at Vinicius de Moraes St...
#
#                                          description experiences_offered  \
# 0  Besides the most iconic's view, our apartment ...                none
# 1  Please note that special rates apply for New Y...                none
# 2  My studio is located in the best  of Ipanema. ...                none
#
#                                neighborhood_overview  ...  \
# 0  Best and favorite neighborhood of Rio. Perfect...  ...
# 1  This is the best spot in Rio. Everything happe...  ...
# 2  The beach, the lagoon, Ipanema is a great loca...  ...
#
#   minimum_minimum_nights maximum_minimum_nights minimum_maximum_nights  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
#
#   maximum_maximum_nights minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                    NaN                    NaN                     NaN
# 1                    NaN                    NaN                     NaN
# 2                    NaN                    NaN                     NaN
#
#    number_of_reviews_ltm calculated_host_listings_count_entire_homes  \
# 0                    NaN                                         NaN
# 1                    NaN                                         NaN
# 2                    NaN                                         NaN
#
#    calculated_host_listings_count_private_rooms  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#    calculated_host_listings_count_shared_rooms
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
# [3 rows x 108 columns]
#               id                            listing_url       scrape_id  \
# 902207  38846703  https://www.airbnb.com/rooms/38846703  20190923212307
# 902208  38847050  https://www.airbnb.com/rooms/38847050  20190923212307
# 902209  38847655  https://www.airbnb.com/rooms/38847655  20190923212307
#
#        last_scraped                                          name  \
# 902207   2019-09-24  Apt COMPLETO em COPACABANA c/TOTAL SEGURANÇA
# 902208   2019-09-24                     Cobertura Cinematografica
# 902209   2019-09-24     Quarto em cobertura em frente à praia III
#
#                                                   summary  \
# 902207  Apartamento quarto e sala COMPLETO para curtas...
# 902208                               Cobertura alto nivel
# 902209  Quarto em cobertura quadriplex com vista lindí...
#
#                                                     space  \
# 902207  Espaço ideal para até 5 pessoas. Cama de casal...
# 902208                                                NaN
# 902209                                                NaN
#
#                                               description experiences_offered  \
# 902207  Apartamento quarto e sala COMPLETO para curtas...                none
# 902208                               Cobertura alto nivel                none
# 902209  Quarto em cobertura quadriplex com vista lindí...                none
#
#        neighborhood_overview  ... minimum_minimum_nights  \
# 902207                   NaN  ...                    3.0
# 902208                   NaN  ...                    1.0
# 902209                   NaN  ...                    1.0
#
#        maximum_minimum_nights minimum_maximum_nights maximum_maximum_nights  \
# 902207                    3.0                 1125.0                 1125.0
# 902208                    1.0                 1125.0                 1125.0
# 902209                    1.0                   30.0                   30.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm  number_of_reviews_ltm  \
# 902207                    3.0                  1125.0                    0.0
# 902208                    1.0                  1125.0                    0.0
# 902209                    1.0                    30.0                    0.0
#
#        calculated_host_listings_count_entire_homes  \
# 902207                                        23.0
# 902208                                         1.0
# 902209                                         0.0
#
#         calculated_host_listings_count_private_rooms  \
# 902207                                           6.0
# 902208                                           0.0
# 902209                                           4.0
#
#         calculated_host_listings_count_shared_rooms
# 902207                                          0.0
# 902208                                          0.0
# 902209                                          0.0
#
# [3 rows x 108 columns]

# %% [markdown]
# ### Visualizando a quantidade de linhas e colunas do dataset

# %%
df.shape # Visualizando a quantidade de linhas e colunas do dataset
# Out:
# (902210, 108)

# %% [markdown]
# ### Visualizando os detalhes do dataset

# %%
df.info() # Exibindo as informações das variáveis do dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 902210 entries, 0 to 902209
# Columns: 108 entries, id to calculated_host_listings_count_shared_rooms
# dtypes: float64(31), int64(15), object(62)
# memory usage: 743.4+ MB

# %% [markdown]
# ### Visualizando as estatísticas das colunas numéricas

# %%
fn_stats.describe(df) # Usando a função que exibe as estatísticas das colunas numéricas
# Out:
#                id         scrape_id  thumbnail_url  medium_url  \
# count   902210.00         902210.00           0.00        0.00
# mean  16335994.95 20189294959368.14            NaN         NaN
# std   10649226.64     7000549923.73            NaN         NaN
# min      14063.00 20180414160018.00            NaN         NaN
# 25%    9503349.00 20181012035542.00            NaN         NaN
# 50%   13979604.00 20190521191438.00            NaN         NaN
# 75%   22698536.00 20191122092441.00            NaN         NaN
# max   43524785.00 20200524171540.00            NaN         NaN
#
#        xl_picture_url      host_id  host_listings_count  \
# count            0.00    902210.00            901750.00
# mean              NaN  65708105.84                 8.53
# std               NaN  67441621.45                46.99
# min               NaN      2616.00                 0.00
# 25%               NaN  13884829.00                 1.00
# 50%               NaN  49895323.00                 1.00
# 75%               NaN  84900656.00                 3.00
# max               NaN 346884508.00              1495.00
#
#        host_total_listings_count  neighbourhood_group_cleansed  latitude  \
# count                  901750.00                          0.00 902210.00
# mean                        8.53                           NaN    -22.97
# std                        46.99                           NaN      0.03
# min                         0.00                           NaN    -23.07
# 25%                         1.00                           NaN    -22.98
# 50%                         1.00                           NaN    -22.97
# 75%                         3.00                           NaN    -22.95
# max                      1495.00                           NaN    -22.75
#
#        longitude  accommodates  bathrooms  bedrooms      beds  square_feet  \
# count  902210.00     902210.00  900486.00 901360.00 899708.00     14048.00
# mean      -43.25          4.21       1.69      1.64      2.60       515.00
# std         0.10          2.61       1.20      1.08      2.07       943.18
# min       -43.74          1.00       0.00      0.00      0.00         0.00
# 25%       -43.32          2.00       1.00      1.00      1.00         0.00
# 50%       -43.20          4.00       1.00      1.00      2.00       210.00
# 75%       -43.19          6.00       2.00      2.00      3.00       753.00
# max       -43.10        160.00     200.00     45.00     86.00     10764.00
#
#        guests_included  minimum_nights  maximum_nights  availability_30  \
# count        902210.00       902210.00       902210.00        902210.00
# mean              1.68            4.55        41617.02            16.68
# std               1.53           20.84      7303340.33            13.06
# min               1.00            1.00            1.00             0.00
# 25%               1.00            1.00           30.00             0.00
# 50%               1.00            2.00         1125.00            23.00
# 75%               2.00            4.00         1125.00            29.00
# max              36.00         1224.00   2147483647.00            30.00
#
#        availability_60  availability_90  availability_365  number_of_reviews  \
# count        902210.00        902210.00         902210.00          902210.00
# mean             35.14            54.28            193.79               7.71
# std              25.93            38.68            153.03              21.79
# min               0.00             0.00              0.00               0.00
# 25%               0.00             0.00              7.00               0.00
# 50%              49.00            77.00            180.00               1.00
# 75%              59.00            89.00            362.00               4.00
# max              60.00            90.00            365.00             401.00
#
#        review_scores_rating  review_scores_accuracy  \
# count             454194.00               453624.00
# mean                  94.44                    9.62
# std                    9.54                    0.93
# min                   20.00                    2.00
# 25%                   93.00                   10.00
# 50%                   98.00                   10.00
# 75%                  100.00                   10.00
# max                  100.00                   10.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                  453797.00              453560.00
# mean                        9.40                   9.78
# std                         1.12                   0.76
# min                         2.00                   2.00
# 25%                         9.00                  10.00
# 50%                        10.00                  10.00
# 75%                        10.00                  10.00
# max                        10.00                  10.00
#
#        review_scores_communication  review_scores_location  \
# count                    453795.00               453657.00
# mean                          9.75                    9.72
# std                           0.80                    0.77
# min                           2.00                    2.00
# 25%                          10.00                   10.00
# 50%                          10.00                   10.00
# 75%                          10.00                   10.00
# max                          10.00                   10.00
#
#        review_scores_value  jurisdiction_names  \
# count            453659.00                0.00
# mean                  9.31                 NaN
# std                   1.04                 NaN
# min                   2.00                 NaN
# 25%                   9.00                 NaN
# 50%                  10.00                 NaN
# 75%                  10.00                 NaN
# max                  10.00                 NaN
#
#        calculated_host_listings_count  reviews_per_month       ano       mes  \
# count                       902210.00          477922.00 902210.00 902210.00
# mean                             6.57               0.62   2018.86      6.32
# std                             25.30               0.86      0.72      3.40
# min                              1.00               0.00   2018.00      1.00
# 25%                              1.00               0.10   2018.00      4.00
# 50%                              1.00               0.27   2019.00      6.00
# 75%                              3.00               0.82   2019.00      9.00
# max                            324.00              97.16   2020.00     12.00
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# count               600999.00               600999.00               600999.00
# mean                     4.60                    5.08                16176.06
# std                     20.76                   21.45              3870402.77
# min                      1.00                    1.00                    1.00
# 25%                      1.00                    1.00                   30.00
# 50%                      2.00                    3.00                 1125.00
# 75%                      4.00                    5.00                 1125.00
# max                   1095.00                 1095.00            999999999.00
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# count               600999.00               600999.00               600999.00
# mean                 16180.88                    4.72                16178.17
# std                3870402.75                   20.91              3870402.76
# min                      1.00                    1.00                    1.00
# 25%                     30.00                    1.00                   30.00
# 50%                   1125.00                    2.20                 1125.00
# 75%                   1125.00                    4.00                 1125.00
# max              999999999.00                 1095.00            999999999.00
#
#        number_of_reviews_ltm  calculated_host_listings_count_entire_homes  \
# count              600999.00                                    600999.00
# mean                    3.03                                         6.13
# std                     7.50                                        26.56
# min                     0.00                                         0.00
# 25%                     0.00                                         1.00
# 50%                     0.00                                         1.00
# 75%                     2.00                                         2.00
# max                   127.00                                       322.00
#
#        calculated_host_listings_count_private_rooms  \
# count                                     600999.00
# mean                                           0.74
# std                                            1.78
# min                                            0.00
# 25%                                            0.00
# 50%                                            0.00
# 75%                                            1.00
# max                                           40.00
#
#        calculated_host_listings_count_shared_rooms
# count                                    600999.00
# mean                                          0.09
# std                                           0.77
# min                                           0.00
# 25%                                           0.00
# 50%                                           0.00
# 75%                                           0.00
# max                                          23.00

# %% [markdown]
# ### Visualizando as estatísticas da colunas categóricas

# %%
df.describe(exclude='number') # Exibindo as estatísticas das colunas categóricas
# Out:
#                                   listing_url last_scraped  \
# count                                  902210       902210
# unique                                  70185           54
# top     https://www.airbnb.com/rooms/15058677   2018-07-14
# freq                                       25        38875
#
#                              name summary  \
# count                      900538  860406
# unique                      81218   76583
# top     Apartamento em Copacabana       .
# freq                         1216    4874
#
#                                                     space  \
# count                                              543496
# unique                                              46381
# top     The apartment is amazing, spacious, quiet and ...
# freq                                                  319
#
#                                               description experiences_offered  \
# count                                              884040              902210
# unique                                              87198                   1
# top     Meu espaço é bom para casais, aventuras indivi...                none
# freq                                                  352              902210
#
#                                     neighborhood_overview  \
# count                                              481672
# unique                                              35964
# top     Copacabana, a name synonym of paradise. The wa...
# freq                                                  786
#
#                                                     notes transit  ...  \
# count                                              284885  476428  ...
# unique                                              22238   35327  ...
# top     Intern Settlement : 1. The maximum number of t...     Sim  ...
# freq                                                 4523     565  ...
#
#        calendar_last_scraped first_review last_review requires_license  \
# count                 902210       477922      477961           902210
# unique                    54         2783        2023                1
# top               2018-07-14   2016-08-15  2018-02-14                f
# freq                   38875         6513       10763           902210
#
#               license instant_bookable is_business_travel_ready  \
# count              43           902210                   902210
# unique              5                2                        1
# top     +1512-6670366                f                        f
# freq               25           556656                   902210
#
#        cancellation_policy require_guest_profile_picture  \
# count               902210                        902210
# unique                   6                             2
# top               flexible                             f
# freq                386758                        887509
#
#        require_guest_phone_verification
# count                            902210
# unique                                2
# top                                   f
# freq                             886462
#
# [4 rows x 62 columns]

# %% [markdown]
# ### Verificando as colunas com valores nulos

# %%
df.isnull().sum() # Somando todos os valores nulos de cada coluna
# Out:
# id                                                   0
# listing_url                                          0
# scrape_id                                            0
# last_scraped                                         0
# name                                              1672
#                                                  ...
# maximum_nights_avg_ntm                          301211
# number_of_reviews_ltm                           301211
# calculated_host_listings_count_entire_homes     301211
# calculated_host_listings_count_private_rooms    301211
# calculated_host_listings_count_shared_rooms     301211
# Length: 108, dtype: int64

# %% [markdown]
# ### Gerando um preview do dataset para um análise rápida

# %%
df.head(100).to_csv(consts.DATASET_PREVIEW) # Criando um arquivo em csv com as 100 primeiras linhas

# %% [markdown]
# ### Conclusões obtidas e as próximas ações para tratar o dataset
#
# - **Colunas que devem ter o tipo de dados corrigido**
#     1. Dt_Customer
# - **Colunas que devem ter valores nulos/vazios tratados**
#     1. Income
# - **Colunas que devem ser convertidas de data para tempo/idade**
#     1. Dt_Cusomer => Days_Since_Enrolled
#     2. Dt_Cusomer => Years_Since_Enrolled
#     3. Year_Birth => Age
# - **Colunas que devem ter categorias mescladas**
#     1. AgeGroup
#     2. Marital_Status
# - **Colunas que devem ser unificadas**
#     1. Children => Kidhome e Teenhome
#     2. MntTotal => MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts e MntGoldProds
#     3. AcceptedCmpTotal => AcceptedCmp1, AcceptedCmp2, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5
#     4. NumTotalPurchases => NumWebPurchases, NumCatalogPurchases, NumStorePurchases
# - **Colunas que devem ser derivadas de outras**
#     1. HasChildren => Children
#     2. MntRegularProd => MntTotal e MntGoldProds
#     3. HasAcceptedCmp => AcceptedCmpTotal
# - **Colunas que devem ter valores outliers tratados**
#     1. Age
#     2. Income
#     3. MntTotal
# - **Colunas que devem ser excluídas por valores únicos**
#     1. ID
# - **Colunas que devem ser excluídas por valores constantes**
#     1. Z_CostContact
#     2. Z_Revenue
# - **Colunas que devem ser excluídas após serem utilizadas como apoio**
#     1. Dt_Cusomer
#     2. Year_Birth
#     3. Kidhome
#     4. Teenhome
#     5. MntWines
#     6. MntFruits
#     7. MntMeatProducts
#     8. MntFishProducts
#     9. MntSweetProducts
#     10. AcceptedCmp1
#     11. AcceptedCmp2
#     12. AcceptedCmp3
#     13. AcceptedCmp4
#     14. AcceptedCmp5
#     15. NumWebPurchases
#     16. NumCatalogPurchases
#     17. NumStorePurchases
